# %% [markdown]
# # Unsupervised Representation Learning With Deep Convolutional Adversarial Networks
# ---
#
# Trained on SVHN

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl

# %%
import torch 
from torch import nn, optim
from torchvision import datasets, transforms
import torch.nn.functional as F

# %%
train_on_gpu = torch.cuda.is_available()
device = torch.device('cuda:0' if train_on_gpu else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## Get the dataset

# %%
transform = transforms.ToTensor()

# %%
train_dataset = datasets.SVHN('../../data', split='train', transform=transform, download=True)
# batch size is set according to recommendations from the dcgan paper
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True)
# Out:
# Using downloaded and verified file: ../../data/train_32x32.mat

# %% [markdown]
# ### Visualize a sample of the data

# %%
dataiter = iter(train_loader)
images, labels = next(dataiter)

# %%
fig = plt.figure(figsize=(25, 4))

for idx in np.arange(20):
    ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
    img = images[idx].numpy()
    img = img.transpose(1, 2, 0)
    ax.imshow(img.squeeze())
    ax.set_title(str(labels[idx].item()))

# %% [markdown]
# ## Define the DCGAN model

# %% [markdown]
# ### Minibatch Discrimination
#
# Implement and use minibatch discrimination from this paper

# %%
class MinibatchDiscrimination(nn.Module):
    def __init__(self, A, B, C):
        super().__init__()
        # dimensions of the transformation tensor
        self.A = A
        self.B = B
        self.C = C
        # create the transformation tensor
        init_tensor = torch.randn(A, B*C) * 0.1
        self.T = nn.Parameter(init_tensor, requires_grad=True)
        self.T.to(device)
        
    def forward(self, x):
        M = x.mm(self.T)
        M = M.view(-1, self.B, self.C)
        
        o_x = torch.Tensor(x.shape[0], self.B).cuda()
        # loop over each image in the batch
        for i in range(x.shape[0]):
            # calculate the L1 norm between each image and the other images
            # sum over the rows
            # shape of results is batch_size x B
            cb = torch.sum(torch.abs(M[i, :] - M), 2) 
            cb = torch.exp(-cb)
            
            o_xi = torch.sum(cb, 0) # output is shape 1 x B
            o_x[i,:] = o_xi
        
        return o_x

# %% [markdown]
# ### Generator

# %%
def frac_conv_layer(in_channels, out_channels, kernel_size, stride=2, padding=1, add_batch_norm=True):
    """
        A helper function to create a fractionally strided convolutional layer, 
        optionally followed by a batch_norm layer
    """
    layers = []
    frac_conv = nn.ConvTranspose2d(in_channels, out_channels, kernel_size,
                                         stride, padding, bias=False)
    layers.append(frac_conv)
    if add_batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    def __init__(self, z_size, conv_dim=32):
        super().__init__()
        
        self.conv_dim = conv_dim
        # fully connected layer to convert z vector into size that can be 
        # used for the first conv_layer
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)
        
        self.frac_conv_1 = frac_conv_layer(conv_dim*4, conv_dim*2, 4, add_batch_norm=True)
        self.frac_conv_2 = frac_conv_layer(conv_dim*2, conv_dim, 4, add_batch_norm=True)
        self.frac_conv_3 = frac_conv_layer(conv_dim, 3, 4, add_batch_norm=False)
        
    def forward(self, x):
        x = self.fc(x)
        x = x.view(-1, self.conv_dim*4, 4, 4)
        x = torch.relu(self.frac_conv_1(x))
        x = torch.relu(self.frac_conv_2(x))
        x = torch.tanh(self.frac_conv_3(x))
        
        return x

# %% [markdown]
# ### Discriminator

# %%
def conv_layer(in_channels, out_channels, kernel_size, stride=2, padding=1, add_batch_norm=True):
    """
        A helper function to create a convolutional layer, 
        optionally followed by a batch_norm layer
    """
    layers = []
    conv = nn.Conv2d(in_channels, out_channels, kernel_size,
                                         stride, padding, bias=False)
    layers.append(conv)
    if add_batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):
    def __init__(self, minibatch_layer, conv_dim=32):
        super().__init__()
    
        self.conv_dim = conv_dim
        
        self.conv1 = conv_layer(3, conv_dim, 4, add_batch_norm=False)
        self.conv2 = conv_layer(conv_dim, conv_dim*2, 4, add_batch_norm=True)
        self.conv3 = conv_layer(conv_dim*2, conv_dim*4, 4, add_batch_norm=True)
        # add a minibatch discrimination layer
        self.mbd = minibatch_layer
        
        self.fc = nn.Linear((conv_dim*4*4*4)+128, 1)
        
    def forward(self, x):
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = F.leaky_relu(self.conv3(x), 0.2)
        x = x.view(-1, self.conv_dim*4*4*4)
        o_xi = self.mbd(x)
        # concatenate the features o_x and x
        out = torch.cat((x, o_xi), 1)
        x = self.fc(out)
        
        return x

# %% [markdown]
# ## Build the complete network

# %%
z_size = 100
conv_dim = 32

G = Generator(z_size, conv_dim)
minibatch_layer = MinibatchDiscrimination(conv_dim*4*4*4, 128, 16)
minibatch_layer.to(device)
D = Discriminator(minibatch_layer, conv_dim)
# put models on the GPU
G = G.to(device);
D = D.to(device);

# %% [markdown]
# ## Weight Initialization
# Initialize weights from a zero-centered normal distribution with a standard deviation of 0.2

# %%
def init_weights(module):
    """
    Takes in a module and initalizes all the weights with values taken from
    a zero-centered normal distribution with a standard deviation of 0.2
    
    Bias is initialized to zero
    """
    classname = module.__class__.__name__
    if classname.find('Conv') != -1 or classname.find('Linear') != -1:
        if hasattr(module, 'weight'):
            module.weight.data.normal_(0.0, 0.2)
        if hasattr(module, 'bias') and module.bias is not None:
            module.bias.data.fill_(0)

# %%
G.apply(init_weights)
D.apply(init_weights)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (mbd): MinibatchDiscrimination()
#   (fc): Linear(in_features=2176, out_features=1, bias=True)
# )

# %% [markdown]
# ## Define loss functions and optimizers

# %%
def real_loss(logits, smooth=True):
    criterion = nn.BCEWithLogitsLoss()
    labels = torch.ones(*logits.shape)*0.9 if smooth else torch.ones(*logits.shape)
    labels = labels.to(device)
    loss = criterion(logits, labels)
    return loss

# %%
def fake_loss(logits):
    labels = torch.zeros_like(logits)
    labels = labels.to(device)
    criterion = nn.BCEWithLogitsLoss()
    
    return criterion(logits, labels)

# %%
# use hyperparameters values recommended by the dcgan paper
lr = 0.0002
betas = (0.5, 0.999)

d_optimizer = optim.Adam(D.parameters(), lr, betas)
g_optimizer = optim.Adam(G.parameters(), lr, betas)

# %% [markdown]
# ## Training Loop

# %%
n_epochs = 50
print_every = 400
generated_samples = []

discriminator_losses = []
generator_losses = []

# %%
# generate fixed z for evaluating the generator
fixed_z = np.random.uniform(-1, 1, size=(images.shape[0], z_size))
fixed_z = torch.from_numpy(fixed_z).float()
fixed_z = fixed_z.to(device)

# %%
for epoch in range(1, n_epochs+1):
    for idx, (real_images, _) in enumerate(train_loader):
        real_images = real_images.to(device)
        # scale images to be between the range -1 to 1
        real_images = real_images * 2 - 1
        
        ##############################################################
        #################   Train the Discriminator   ################
        ##############################################################
        d_optimizer.zero_grad()
        
        # pass real images to the discriminator
        real_logits = D(real_images)
        d_real_loss = real_loss(real_logits,smooth=False)
        
        # pass fake images to the discriminator 
        z = np.random.uniform(-1, 1, size=(images.shape[0], z_size))
        z = torch.from_numpy(z).float()
        z = z.to(device)
        
        fake_images = G(z)
        fake_logits = D(fake_images)
        d_fake_loss = fake_loss(fake_logits)
        
        # combine real and fake loss to get total discriminator loss
        d_loss = d_real_loss + d_fake_loss
        # backpropagate and update the gradients of the discriminator
        d_loss.backward()
        d_optimizer.step()
        
        ###############################################################
        #################   Train the Generator    ####################
        ###############################################################
        g_optimizer.zero_grad()
        
        # generate fake images 
        z = np.random.uniform(-1, 1, size=(images.shape[0], z_size))
        z = torch.from_numpy(z).float()
        z = z.to(device)
        
        fake_images = G(z)
        
        # pass fake images to the discriminator
        fake_logits = D(fake_images)
        g_loss = real_loss(fake_logits, smooth=False)
        
        # backpropagate and update the gradients of the generator
        g_loss.backward()
        g_optimizer.step()
        
        if idx % print_every == 0:
            discriminator_losses.append(d_loss.item())
            generator_losses.append(g_loss.item())
            # print statistics
            print(f'Epoch: {epoch}/{n_epochs}     Discriminator loss: {d_loss: .3f}',
                  f'    Generator loss: {g_loss: .3f}')
    else: 
        # generate and store sample images for this epoch
        G.eval() # put G in eval mode
        fake_images = G(fixed_z)
        generated_samples.append(fake_images)
        G.train() # put G in train mode
# Out:
# Epoch: 1/50     Discriminator loss:  4.311     Generator loss:  4.500
# Epoch: 1/50     Discriminator loss:  0.108     Generator loss:  7.598
# Epoch: 2/50     Discriminator loss:  0.035     Generator loss:  8.161
# Epoch: 2/50     Discriminator loss:  0.374     Generator loss:  3.213
# Epoch: 3/50     Discriminator loss:  0.086     Generator loss:  5.693
# Epoch: 3/50     Discriminator loss:  0.056     Generator loss:  5.494
# Epoch: 4/50     Discriminator loss:  0.123     Generator loss:  5.696
# Epoch: 4/50     Discriminator loss:  0.108     Generator loss:  4.839
# Epoch: 5/50     Discriminator loss:  0.045     Generator loss:  4.471
# Epoch: 5/50     Discriminator loss:  0.069     Generator loss:  4.945
# Epoch: 6/50     Discriminator loss:  0.061     Generator loss:  6.013
# Epoch: 6/50     Discriminator loss:  0.032     Generator loss:  4.510
# Epoch: 7/50     Discriminator loss:  0.237     Generator loss:  4.394
# Epoch: 7/50     Discriminator loss:  0.306     Generator loss:  4.854
# Epoch: 8/50     Discriminator loss:  0.103     Generator loss:  5.436
# Epoch: 8/50     Discriminator loss:  0.117     Generator loss:  5.709
# Epoch: 9/50     Discriminator loss:  0.181     Generator loss:  4.754
# Epoch: 9/50     Discriminator loss:  0.240     Generator loss:  3.455
# Epoch: 10/50     Discriminator loss:  0.145     Generator loss:  3.971
# Epoch: 10/50     Discriminator loss:  0.339     Generator loss:  4.618
# Epoch: 11/50     Discriminator loss:  0.345     Generator loss:  3.883
# Epoch: 11/50     Discriminator loss:  0.761     Generator loss:  2.946
# Epoch: 12/50     Discriminator loss:  0.575     Generator loss:  3.519
# Epoch: 12/50     Discriminator loss:  0.320     Generator loss:  2.842
# Epoch: 13/50     Discriminator loss:  0.600     Generator loss:  3.297
# Epoch: 13/50     Discriminator loss:  0.517     Generator loss:  2.967
# Epoch: 14/50     Discriminator loss:  0.380     Generator loss:  3.014
# Epoch: 14/50     Discriminator loss:  0.539     Generator loss:  2.510
# Epoch: 15/50     Discriminator loss:  0.743     Generator loss:  1.390
# Epoch: 15/50     Discriminator loss:  0.650     Generator loss:  2.118
# Epoch: 16/50     Discriminator loss:  0.867     Generator loss:  1.659
# Epoch: 16/50     Discriminator loss:  0.376     Generator loss:  2.566
# Epoch: 17/50     Discriminator loss:  0.562     Generator loss:  2.486
# Epoch: 17/50     Discriminator loss:  0.354     Generator loss:  2.688
# Epoch: 18/50     Discriminator loss:  0.206     Generator loss:  2.958
# Epoch: 18/50     Discriminator loss:  0.264     Generator loss:  3.694
# Epoch: 19/50     Discriminator loss:  0.254     Generator loss:  2.987
# Epoch: 19/50     Discriminator loss:  0.158     Generator loss:  4.812
# Epoch: 20/50     Discriminator loss:  0.120     Generator loss:  4.427
# Epoch: 20/50     Discriminator loss:  0.089     Generator loss:  3.867
# Epoch: 21/50     Discriminator loss:  0.131     Generator loss:  4.054
# Epoch: 21/50     Discriminator loss:  0.090     Generator loss:  5.391
# Epoch: 22/50     Discriminator loss:  0.072     Generator loss:  5.346
# Epoch: 22/50     Discriminator loss:  0.036     Generator loss:  5.356
# Epoch: 23/50     Discriminator loss:  0.117     Generator loss:  6.741
# Epoch: 23/50     Discriminator loss:  0.112     Generator loss:  4.973
# Epoch: 24/50     Discriminator loss:  0.140     Generator loss:  4.939
# Epoch: 24/50     Discriminator loss:  0.554     Generator loss:  4.833
# Epoch: 25/50     Discriminator loss:  0.146     Generator loss:  6.261
# Epoch: 25/50     Discriminator loss:  0.094     Generator loss:  6.113
# Epoch: 26/50     Discriminator loss:  0.293     Generator loss:  4.429
# Epoch: 26/50     Discriminator loss:  0.129     Generator loss:  4.494
# Epoch: 27/50     Discriminator loss:  0.353     Generator loss:  4.489
# Epoch: 27/50     Discriminator loss:  0.036     Generator loss:  6.690
# Epoch: 28/50     Discriminator loss:  0.173     Generator loss:  3.606
# Epoch: 28/50     Discriminator loss:  0.091     Generator loss:  4.449
# Epoch: 29/50     Discriminator loss:  0.127     Generator loss:  5.787
# Epoch: 29/50     Discriminator loss:  0.136     Generator loss:  4.451
# Epoch: 30/50     Discriminator loss:  0.890     Generator loss:  0.427
# Epoch: 30/50     Discriminator loss:  0.103     Generator loss:  5.856
# Epoch: 31/50     Discriminator loss:  0.095     Generator loss:  6.836
# Epoch: 31/50     Discriminator loss:  0.052     Generator loss:  5.770
# Epoch: 32/50     Discriminator loss:  0.061     Generator loss:  6.829
# Epoch: 32/50     Discriminator loss:  0.266     Generator loss:  4.400
# Epoch: 33/50     Discriminator loss:  0.036     Generator loss:  7.495
# Epoch: 33/50     Discriminator loss:  0.467     Generator loss:  9.883
# Epoch: 34/50     Discriminator loss:  0.057     Generator loss:  7.024
# Epoch: 34/50     Discriminator loss:  0.436     Generator loss:  2.447
# Epoch: 35/50     Discriminator loss:  0.106     Generator loss:  5.713
# Epoch: 35/50     Discriminator loss:  0.125     Generator loss:  5.709
# Epoch: 36/50     Discriminator loss:  0.050     Generator loss:  6.886
# Epoch: 36/50     Discriminator loss:  0.091     Generator loss:  6.966
# Epoch: 37/50     Discriminator loss:  0.096     Generator loss:  6.595
# Epoch: 37/50     Discriminator loss:  0.057     Generator loss:  5.517
# Epoch: 38/50     Discriminator loss:  0.086     Generator loss:  6.683
# Epoch: 38/50     Discriminator loss:  0.123     Generator loss:  8.366
# Epoch: 39/50     Discriminator loss:  0.055     Generator loss:  7.399
# Epoch: 39/50     Discriminator loss:  0.023     Generator loss:  8.093
# Epoch: 40/50     Discriminator loss:  1.602     Generator loss:  0.086
# Epoch: 40/50     Discriminator loss:  0.042     Generator loss:  7.580
# Epoch: 41/50     Discriminator loss:  0.053     Generator loss:  6.321
# Epoch: 41/50     Discriminator loss:  0.092     Generator loss:  4.025
# Epoch: 42/50     Discriminator loss:  0.024     Generator loss:  7.270
# Epoch: 42/50     Discriminator loss:  0.074     Generator loss:  7.665
# Epoch: 43/50     Discriminator loss:  0.086     Generator loss:  8.490
# Epoch: 43/50     Discriminator loss:  0.058     Generator loss:  6.282
# Epoch: 44/50     Discriminator loss:  0.141     Generator loss:  4.915
# Epoch: 44/50     Discriminator loss:  0.076     Generator loss:  8.178
# Epoch: 45/50     Discriminator loss:  0.103     Generator loss:  6.888
# Epoch: 45/50     Discriminator loss:  0.060     Generator loss:  6.366
# Epoch: 46/50     Discriminator loss:  0.199     Generator loss:  5.532
# Epoch: 46/50     Discriminator loss:  0.083     Generator loss:  5.605
# Epoch: 47/50     Discriminator loss:  0.037     Generator loss:  8.830
# Epoch: 47/50     Discriminator loss:  0.054     Generator loss:  7.260
# Epoch: 48/50     Discriminator loss:  1.008     Generator loss:  4.376
# Epoch: 48/50     Discriminator loss:  0.101     Generator loss:  7.850
# Epoch: 49/50     Discriminator loss:  0.055     Generator loss:  9.158
# Epoch: 49/50     Discriminator loss:  0.133     Generator loss:  4.282
# Epoch: 50/50     Discriminator loss:  0.040     Generator loss:  8.544
# Epoch: 50/50     Discriminator loss:  0.046     Generator loss:  8.846

# %% [markdown]
# **save samples**

# %%
with open('saved_samples/svhn_samples_with_mbd', 'wb') as f:
    pkl.dump(generated_samples, f)

# %% [markdown]
# ## Plot training losses

# %%
plt.plot(discriminator_losses, label='Discriminator', alpha=0.5)
plt.plot(generator_losses, label='Generator', alpha=0.5)
plt.title('Training losses')
plt.legend()

# %% [markdown]
# ## Evaluate the model

# %% [markdown]
# #### Show generated samples

# %%
with open('saved_samples/svhn_samples_with_mbd', 'rb') as f:
    generated_samples = pkl.load(f)

# %%
rows = 10
cols = 10

fig, ax = plt.subplots(figsize=(20, 15), nrows=rows, ncols=cols, sharex=True, sharey=True)


for epoch_sample, ax_row in zip(generated_samples[::int(len(generated_samples)/rows)], ax):
    for img, ax_col in zip(epoch_sample[::int(len(epoch_sample)/cols)], ax_row):
        img = img.cpu().detach() # detach tensor from its history
        img = img.numpy() # convert to numpy array
        img = img.transpose(1, 2, 0)
        img = ((img + 1) * 255 / (2)).astype(np.uint8) # rescale to 0-255
        ax_col.imshow(img)
        ax_col.xaxis.set_visible(False)
        ax_col.yaxis.set_visible(False)
