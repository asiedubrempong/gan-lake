# %% [markdown]
# # MNIST GAN
# ---

# %% [markdown]
# Pytorch implementation of the Generative Adversarial Networks paper (Goodfellow et.al., 2014). Model is trained on MNIST dataset.
#
# Link to paper: https://arxiv.org/abs/1406.2661
#
# <img src='../../assets/gan_pipeline.png'/>

# %% [markdown]
# ## Import libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pickle as pkl

# %%
import torch
from torch import nn, optim
from torchvision import datasets, transforms
import torch.nn.functional as F

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# ## Get the data

# %%
transform = transforms.ToTensor()

path = '../../data/' # path to folder that contains the data

train_dataset = datasets.MNIST(path, train=True, transform=transform, download=True)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=32, shuffle=True)

# %% [markdown]
# ### Visualize a batch of data

# %%
data_iter = iter(train_loader)
images, labels = next(data_iter)

# %%
fig = plt.figure(figsize=(25, 5))

for i in range(1, 21):
    img = images[i].numpy()
    ax = fig.add_subplot(2, 10, i, xticks=[], yticks=[])
    ax.imshow(np.squeeze(img), cmap='gray')
    ax.set_title(str(labels[i].item()))

# %% [markdown]
# ## Define GAN model

# %% [markdown]
# ### Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, input_dim, hidden_layer_dim):
        super().__init__()
        
        self.fc1 = nn.Linear(input_dim, hidden_layer_dim*4)
        self.fc2 = nn.Linear(hidden_layer_dim*4, hidden_layer_dim*2)
        self.fc3 = nn.Linear(hidden_layer_dim*2, hidden_layer_dim)
        self.fc4 = nn.Linear(hidden_layer_dim, 1)
        
        self.dropout = nn.Dropout(0.3)
    
    def forward(self, x):
        # matrix multiplication -> leaky relu -> dropout
        x = self.dropout(F.leaky_relu(self.fc1(x), 0.2))
        x = self.dropout(F.leaky_relu(self.fc2(x), 0.2))
        x = self.dropout(F.leaky_relu(self.fc3(x), 0.2))
        x = self.fc4(x)
        return x

# %% [markdown]
# ### Generator

# %%
class Generator(nn.Module):
    def __init__(self, z_dim, hidden_layer_dim, output_dim):
        super().__init__()
        
        self.fc1 = nn.Linear(z_dim, hidden_layer_dim)
        self.fc2 = nn.Linear(hidden_layer_dim, hidden_layer_dim*2)
        self.fc3 = nn.Linear(hidden_layer_dim*2, hidden_layer_dim*4)
        self.fc4 = nn.Linear(hidden_layer_dim*4, output_dim)
        self.dropout = nn.Dropout(0.3)
        
    def forward(self, x):
        # matrix multiplication -> leaky relu -> dropout
        x = self.dropout(F.leaky_relu(self.fc1(x), 0.2))
        x = self.dropout(F.leaky_relu(self.fc2(x), 0.2))
        x = self.dropout(F.leaky_relu(self.fc3(x), 0.2))
        # output uses a tanh activation function to ensure that
        # values are in the range -1 to 1
        x = torch.tanh(self.fc4(x))
        return x

# %% [markdown]
# ## Create Models, Loss functions and Optimizers

# %% [markdown]
# ### Models

# %%
d_input_dim = 28 * 28
hidden_layer_dim = 32

z_dim = 100
g_output_dim = 28*28

# %%
D = Discriminator(d_input_dim, hidden_layer_dim)
G = Generator(z_dim, hidden_layer_dim, g_output_dim)

# %%
D.to(device)
G.to(device)
# Out:
# Generator(
#   (fc1): Linear(in_features=100, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=784, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %% [markdown]
# ### Optimizers

# %%
d_optimizer = optim.Adam(D.parameters(), lr=0.002)
g_optimizer = optim.Adam(G.parameters(), lr=0.002)

# %% [markdown]
# ### Loss functions

# %%
def real_loss(logits, smooth=False):
    criterion = nn.BCEWithLogitsLoss()
    labels = torch.ones(*logits.shape) * 0.9 if smooth else torch.ones(*logits.shape)
    labels = labels.to(device)
    loss = criterion(logits, labels)
    return loss

# %%
def fake_loss(logits):
    criterion = nn.BCEWithLogitsLoss()
    labels = torch.zeros(*logits.shape)
    labels = labels.to(device)
    loss = criterion(logits, labels)
    return loss

# %% [markdown]
# ## Training loop

# %%
losses = []
samples = []

# %%
n_epochs = 100
print_every = 800

for epoch in range(1, n_epochs+1):
    for batch_i, (real_images, _) in enumerate(train_loader):
        real_images = real_images.to(device)
        # flatten the images
        real_images = real_images.view(-1, 28*28)
        batch_size = real_images.shape[0]
        
        # create a constant z vector to be used to evaluate the generator
        fixed_z = np.random.uniform(-1, 1, (batch_size, z_dim))
        fixed_z = torch.from_numpy(fixed_z).float()
        fixed_z = fixed_z.to(device)
        
        ##########################################################
        ################## Train the Discriminator ###############
        ##########################################################
        d_optimizer.zero_grad()
        
        # scale real images to be between -1 and 1
        real_images = real_images * 2 - 1
        # first pass real images from the training set
        real_logits = D(real_images)
        d_real_loss = real_loss(real_logits, smooth=True)
        
        # pass fake generated images to the discriminator
        z = np.random.uniform(-1, 1, (batch_size, z_dim))
        z = torch.from_numpy(z).float()
        z = z.to(device)
        
        fake_images = G(z)
        fake_logits = D(fake_images)
        d_fake_loss = fake_loss(fake_logits)
        
        # sum up the losses and backpropagate
        d_loss = d_real_loss + d_fake_loss
        d_loss.backward()
        d_optimizer.step()
        
        
        ##########################################################
        ################## Train the Generator ###################
        ##########################################################
        g_optimizer.zero_grad()
        
        # generate images and pass to discriminator
        z = np.random.uniform(-1, 1, (batch_size, z_dim))
        z = torch.from_numpy(z).float()
        z = z.to(device)
        
        fake_images = G(z)
        fake_logits = D(fake_images)
        # use real loss function because generator seeks to maximize
        # the probability of the discriminator mistaking a generated 
        # image for a real image
        g_loss = real_loss(fake_logits)
        g_loss.backward()
        g_optimizer.step()
        
        # print statistics
        if batch_i % print_every == 0:
            print(f'Epoch: {epoch}/{n_epochs}  Discriminator loss: {d_loss:.3f}',
                  f'Generator loss: {g_loss:.3f}')
    else:
        losses.append((d_loss.item(), g_loss.item()))
        
        # generate and save a sample of images
        G.eval() # put model in evaluation mode
        fake_images = G(fixed_z)
        samples.append(fake_images)
        G.train() # put model back in training mode
# Out:
# Epoch: 1/100  Discriminator loss: 1.377 Generator loss: 0.701
# Epoch: 1/100  Discriminator loss: 1.623 Generator loss: 0.735
# Epoch: 1/100  Discriminator loss: 1.160 Generator loss: 0.741
# Epoch: 2/100  Discriminator loss: 1.131 Generator loss: 1.299
# Epoch: 2/100  Discriminator loss: 1.183 Generator loss: 2.197
# Epoch: 2/100  Discriminator loss: 1.118 Generator loss: 1.127
# Epoch: 3/100  Discriminator loss: 1.106 Generator loss: 1.358
# Epoch: 3/100  Discriminator loss: 1.517 Generator loss: 0.892
# Epoch: 3/100  Discriminator loss: 1.241 Generator loss: 1.382
# Epoch: 4/100  Discriminator loss: 1.263 Generator loss: 1.059
# Epoch: 92/100  Discriminator loss: 1.170 Generator loss: 1.077
# Epoch: 92/100  Discriminator loss: 1.198 Generator loss: 1.025
# Epoch: 92/100  Discriminator loss: 1.289 Generator loss: 1.000
# Epoch: 93/100  Discriminator loss: 1.222 Generator loss: 1.206
# Epoch: 93/100  Discriminator loss: 1.114 Generator loss: 1.415
# Epoch: 93/100  Discriminator loss: 1.193 Generator loss: 1.486
# Epoch: 94/100  Discriminator loss: 1.271 Generator loss: 1.003
# Epoch: 94/100  Discriminator loss: 1.173 Generator loss: 1.411
# Epoch: 94/100  Discriminator loss: 1.270 Generator loss: 1.454
# Epoch: 95/100  Discriminator loss: 1.159 Generator loss: 1.063
# Epoch: 95/100  Discriminator loss: 1.158 Generator loss: 1.446
# Epoch: 95/100  Discriminator loss: 1.239 Generator loss: 1.144
# Epoch: 96/100  Discriminator loss: 1.100 Generator loss: 1.190
# Epoch: 96/100  Discriminator loss: 1.187 Generator loss: 1.275
# Epoch: 96/100  Discriminator loss: 1.231 Generator loss: 1.290
# Epoch: 97/100  Discriminator loss: 1.214 Generator loss: 1.102
# Epoch: 97/100  Discriminator loss: 1.237 Generator loss: 1.108
# Epoch: 97/100  Discriminator loss: 1.243 Generator loss: 1.069
# Epoch: 98/100  Discriminator loss: 1.418 Generator loss: 1.064
# Epoch: 98/100  Discriminator loss: 1.182 Generator loss: 1.325
# Epoch: 98/100  Discriminator loss: 1.221 Generator loss: 1.133
# Epoch: 99/100  Discriminator loss: 1.118 Generator loss: 1.045
# Epoch: 99/100  Discriminator loss: 1.261 Generator loss: 1.035
# Epoch: 99/100  Discriminator loss: 0.986 Generator loss: 1.129
# Epoch: 100/100  Discriminator loss: 1.199 Generator loss: 1.209
# Epoch: 100/100  Discriminator loss: 1.246 Generator loss: 1.199
# Epoch: 100/100  Discriminator loss: 1.115 Generator loss: 1.513

# %% [markdown]
# save generated samples

# %%
with open('mnist_generated_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)

# %% [markdown]
# ### Plot the losses

# %%
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator loss')
plt.plot(losses.T[1], label='Generator loss')
plt.title('Training losses')
plt.legend()

# %% [markdown]
# ## Display samples generated during training

# %%
with open('mnist_generated_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
rows = 10
cols = 10

fig, axes = plt.subplots(figsize=(20, 15), nrows=rows, ncols=cols, sharex=True, sharey=True)

for epoch_sample, axes_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(epoch_sample[::int(len(epoch_sample)/cols)], axes_row):
        img = img.cpu().detach()
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# ## Sample from the generator

# %%
# generate new random z
sample_batch_size = 20
z = np.random.uniform(-1, 1, size=(sample_batch_size, z_dim))
z = torch.from_numpy(z).float()
z = z.to(device)

# %%
G.eval() # put model in eval mode

generated_images = G(z)

# %% [markdown]
# display generated images

# %%
generated_images = generated_images.view(-1, 28, 28)
generated_images = generated_images.cpu().detach().numpy()

# %%
fig = plt.figure(figsize=(20, 10))

for i in np.arange(20):
    ax = fig.add_subplot(4, 5, i+1, xticks=[], yticks=[])
    ax.imshow(generated_images[i], cmap='gray')
